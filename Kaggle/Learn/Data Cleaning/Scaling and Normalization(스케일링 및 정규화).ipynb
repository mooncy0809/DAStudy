# %% [markdown]
# ### Scaling vs Normalization
# 스케일링과 정규화가 혼동되기 쉬운 이유 중 하나는 두 용어가 때때로 상호 교환적으로 사용되기 때문이다. 두 경우 모두 숫자 변수의 값을 변환하여 변환된 데이터가 특성을 가지도록 한다. 차이점은 스케일링에서는 데이터 범위를 변경하는 반면 정규화에서는 데이터 분포의 모양을 변경한다는 것이다.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
